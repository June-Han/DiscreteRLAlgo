# %%
# Connect to Google drive to save your model, etc.,

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Installation and setup
#
# The gym environment requires an older version numpy (and corresponding packages). <br>
# The following cell contains the `requirements.txt` to setup the python environment used in the rest of this notebook.

# %%
# %%writefile requirements.txt
#
# cloudpickle==3.1.1
# contourpy==1.3.0
# cycler==0.12.1
# filelock==3.18.0
# fonttools==4.56.0
# fsspec==2025.3.0
# gym==0.26.2
# gym-notices==0.0.8
# importlib_metadata==8.6.1
# importlib_resources==6.5.2
# Jinja2==3.1.6
# kiwisolver==1.4.7
# MarkupSafe==3.0.2
# matplotlib==3.9.4
# mpmath==1.3.0
# networkx==3.2.1
# numpy==1.24.2
# nvidia-cublas-cu12==12.4.5.8
# nvidia-cuda-cupti-cu12==12.4.127
# nvidia-cuda-nvrtc-cu12==12.4.127
# nvidia-cuda-runtime-cu12==12.4.127
# nvidia-cudnn-cu12==9.1.0.70
# nvidia-cufft-cu12==11.2.1.3
# nvidia-curand-cu12==10.3.5.147
# nvidia-cusolver-cu12==11.6.1.9
# nvidia-cusparse-cu12==12.3.1.170
# nvidia-cusparselt-cu12==0.6.2
# nvidia-nccl-cu12==2.21.5
# nvidia-nvjitlink-cu12==12.4.127
# nvidia-nvtx-cu12==12.4.127
# packaging==24.2
# pillow==11.1.0
# ply==3.11
# pygame==2.6.1
# pyparsing==3.2.1
# python-dateutil==2.9.0.post0
# six==1.17.0
# sympy==1.13.1
# torch==2.6.0
# tqdm==4.67.1
# triton==3.2.0
# zipp==3.21.0
# pyRDDLGym
# Out:
# Overwriting requirements.txt

# %% [markdown]
# Now install the requirements.
#
# You may be asked to restart the session to load the installed versions of the packages. If so, restart the session and continue using the notebook

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: cloudpickle==3.1.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 2)) (3.1.1)
# Collecting contourpy==1.3.0 (from -r requirements.txt (line 3))
#   Downloading contourpy-1.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: cycler==0.12.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: filelock==3.18.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (3.18.0)
# Collecting fonttools==4.56.0 (from -r requirements.txt (line 6))
#   Downloading fonttools-4.56.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.9/101.9 kB 2.9 MB/s eta 0:00:00
# Collecting fsspec==2025.3.0 (from -r requirements.txt (line 7))
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting gym==0.26.2 (from -r requirements.txt (line 8))
#   Downloading gym-0.26.2.tar.gz (721 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.7/721.7 kB 18.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting gym-notices==0.0.8 (from -r requirements.txt (line 9))
#   Downloading gym_notices-0.0.8-py3-none-any.whl.metadata (1.0 kB)
# Collecting importlib_metadata==8.6.1 (from -r requirements.txt (line 10))
#   Downloading importlib_metadata-8.6.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: importlib_resources==6.5.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 11)) (6.5.2)
# Requirement already satisfied: Jinja2==3.1.6 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 12)) (3.1.6)
# Collecting kiwisolver==1.4.7 (from -r requirements.txt (line 13))
#   Downloading kiwisolver-1.4.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: MarkupSafe==3.0.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 14)) (3.0.2)
# Collecting matplotlib==3.9.4 (from -r requirements.txt (line 15))
#   Downloading matplotlib-3.9.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: mpmath==1.3.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 16)) (1.3.0)
# Collecting networkx==3.2.1 (from -r requirements.txt (line 17))
#   Downloading networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting numpy==1.24.2 (from -r requirements.txt (line 18))
#   Downloading numpy-1.24.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from -r requirements.txt (line 19))
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from -r requirements.txt (line 20))
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from -r requirements.txt (line 21))
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from -r requirements.txt (line 22))
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from -r requirements.txt (line 23))
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from -r requirements.txt (line 24))
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from -r requirements.txt (line 25))
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from -r requirements.txt (line 26))
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from -r requirements.txt (line 27))
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.2 (from -r requirements.txt (line 28))
#   Downloading nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from -r requirements.txt (line 29))
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from -r requirements.txt (line 30))
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from -r requirements.txt (line 31))
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: packaging==24.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 32)) (24.2)
# Requirement already satisfied: pillow==11.1.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 33)) (11.1.0)
# Collecting ply==3.11 (from -r requirements.txt (line 34))
#   Downloading ply-3.11-py2.py3-none-any.whl.metadata (844 bytes)
# Collecting pygame==2.6.1 (from -r requirements.txt (line 35))
#   Downloading pygame-2.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting pyparsing==3.2.1 (from -r requirements.txt (line 36))
#   Downloading pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 37)) (2.9.0.post0)
# Requirement already satisfied: six==1.17.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 38)) (1.17.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 39)) (1.13.1)
# Requirement already satisfied: torch==2.6.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 40)) (2.6.0+cpu)
# Requirement already satisfied: tqdm==4.67.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 41)) (4.67.1)
# Collecting triton==3.2.0 (from -r requirements.txt (line 42))
#   Downloading triton-3.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: zipp==3.21.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 43)) (3.21.0)
# Collecting pyRDDLGym (from -r requirements.txt (line 44))
#   Downloading pyRDDLGym-2.2-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r requirements.txt (line 40)) (4.13.1)
# Collecting gymnasium (from pyRDDLGym->-r requirements.txt (line 44))
#   Downloading gymnasium-1.1.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from pyRDDLGym->-r requirements.txt (line 44)) (3.0.1)
# Collecting farama-notifications>=0.0.1 (from gymnasium->pyRDDLGym->-r requirements.txt (line 44))
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Downloading contourpy-1.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.2/323.2 kB 28.9 MB/s eta 0:00:00
# Downloading fonttools-4.56.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 103.1 MB/s eta 0:00:00
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 19.0 MB/s eta 0:00:00
# Downloading gym_notices-0.0.8-py3-none-any.whl (3.0 kB)
# Downloading importlib_metadata-8.6.1-py3-none-any.whl (26 kB)
# Downloading kiwisolver-1.4.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 81.9 MB/s eta 0:00:00
# Downloading matplotlib-3.9.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 119.2 MB/s eta 0:00:00
# Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 83.1 MB/s eta 0:00:00
# Downloading numpy-1.24.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 154.6 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 147.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 75.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 704.9 kB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 1.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 25.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 1.5 MB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl (150.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 8.1 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 1.7 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 89.6 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.5 MB/s eta 0:00:00
# Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 4.6 MB/s eta 0:00:00
# Downloading pygame-2.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 143.0 MB/s eta 0:00:00
# Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 kB 10.6 MB/s eta 0:00:00
# Downloading triton-3.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (253.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.2/253.2 MB 1.5 MB/s eta 0:00:00
# Downloading pyRDDLGym-2.2-py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0/100.0 kB 9.9 MB/s eta 0:00:00
# Downloading gymnasium-1.1.1-py3-none-any.whl (965 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 kB 66.6 MB/s eta 0:00:00
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Building wheels for collected packages: gym
#   Building wheel for gym (pyproject.toml) ... done
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827727 sha256=0f719992647bc947a7a59a07f13941d7d59abda1cecfc5b1bc64b17a8f69b9c1
#   Stored in directory: /root/.cache/pip/wheels/1c/77/9e/9af5470201a0b0543937933ee99ba884cd237d2faefe8f4d37
# Successfully built gym
# Installing collected packages: triton, ply, nvidia-cusparselt-cu12, gym-notices, farama-notifications, pyparsing, pygame, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, kiwisolver, importlib_metadata, fsspec, fonttools, nvidia-cusparse-cu12, nvidia-cudnn-cu12, gymnasium, gym, contourpy, nvidia-cusolver-cu12, matplotlib, pyRDDLGym
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.2.3
#     Uninstalling pyparsing-3.2.3:
#       Successfully uninstalled pyparsing-3.2.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.4.2
#     Uninstalling networkx-3.4.2:
#       Successfully uninstalled networkx-3.4.2
#   Attempting uninstall: kiwisolver
#     Found existing installation: kiwisolver 1.4.8
#     Uninstalling kiwisolver-1.4.8:
#       Successfully uninstalled kiwisolver-1.4.8
#   Attempting uninstall: importlib_metadata
#     Found existing installation: importlib-metadata 4.6.4
#     Uninstalling importlib-metadata-4.6.4:
#       Successfully uninstalled importlib-metadata-4.6.4
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: fonttools
#     Found existing installation: fonttools 4.57.0
#     Uninstalling fonttools-4.57.0:
#       Successfully uninstalled fonttools-4.57.0
#   Attempting uninstall: contourpy
#     Found existing installation: contourpy 1.3.1
#     Uninstalling contourpy-1.3.1:
#       Successfully uninstalled contourpy-1.3.1
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.24.2 which is incompatible.
# jax 0.5.2 requires numpy>=1.25, but you have numpy 1.24.2 which is incompatible.
# jaxlib 0.5.1 requires numpy>=1.25, but you have numpy 1.24.2 which is incompatible.
# treescope 0.1.9 requires numpy>=1.25.2, but you have numpy 1.24.2 which is incompatible.
# Successfully installed contourpy-1.3.0 farama-notifications-0.0.4 fonttools-4.56.0 fsspec-2025.3.0 gym-0.26.2 gym-notices-0.0.8 gymnasium-1.1.1 importlib_metadata-8.6.1 kiwisolver-1.4.7 matplotlib-3.9.4 networkx-3.2.1 numpy-1.24.2 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-cusparselt-cu12-0.6.2 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 ply-3.11 pyRDDLGym-2.2 pygame-2.6.1 pyparsing-3.2.1 triton-3.2.0

# %% [markdown]
# We will use a discretized version of
# the [elevator domain](https://ataitler.github.io/IPPC2023/elevator.html) from the International Planning Competition, 2023.
#
# Install the pyRDDL gym environment using the given repository.

# %%
# !pip install -q git+https://github.com/tasbolat1/pyRDDLGym.git --force-reinstall

## Install other packages if needed
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.5/102.5 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 88.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 131.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 124.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.2/326.2 kB 29.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 130.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 71.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 kB 11.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 21.7 MB/s eta 0:00:00
#   Building wheel for pyRDDLGym (pyproject.toml) ... done

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import copy
import itertools
import numpy as np
import random
import tqdm
import matplotlib.pyplot as plt
from collections import deque

from pyRDDLGym.Visualizer.MovieGenerator import MovieGenerator # loads visualizer utilites
from IPython.display import Image, display, clear_output # for displaying gifs in colab
from pyRDDLGym.Elevator import Elevator # imports Discrete Elevator

## Add more imports here as required
# Out:
# <ipython-input-2-584059c398d6>:14: UserWarning: cv2 is not installed: save_as_mp4 option will be disabled.
#   from pyRDDLGym.Visualizer.MovieGenerator import MovieGenerator # loads visualizer utilites

# %% [markdown]
# # Environment Initialization

# %%
## IMPORTANT: Do not change the instance of the environment.
env = Elevator(instance = 5)

print('Discrete environment actions:')
print(env.disc_actions)
print('Continuous environment actions:')
print(env.base_env.action_space)
print(f"Observation space size for the discrete Elevator Environment: {len(env.disc_states)}")
# Out:
# /usr/local/lib/python3.11/dist-packages/pyRDDLGym/Core/Env/RDDLConstraints.py:85: UserWarning: Constraint does not have a structure of <action or state fluent> <op> <rhs>, where:
# <op> is one of {<=, <, >=, >}
# <rhs> is a deterministic function of non-fluents or constants only.
# >> ( sum_{?f: floor} [ elevator-at-floor(?e, ?f) ] ) == 1
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pyRDDLGym/Examples /usr/local/lib/python3.11/dist-packages/pyRDDLGym/Examples/manifest.csv
# Available example environment(s):
# MountainCar -> A simple continuous MDP for the classical mountain car control problem.
# HVAC -> Multi-zone and multi-heater HVAC control problem
# PowerGen_discrete -> A simple power generation problem loosely modeled on the problem of unit commitment.
# PowerGen_continuous -> A continuous simple power generation problem loosely modeled on the problem of unit commitment.
# Traffic -> BLX/QTM traffic model.
# Reservoir_discrete -> Discrete version of management of the water level in interconnected reservoirs.
# Reservoir_continuous -> Continuous action version of management of the water level in interconnected reservoirs.
# CartPole_discrete -> A simple continuous state MDP for the classical cart-pole system by Rich Sutton, with discrete actions that apply a constant force on either the left or right side of the cart.
# CartPole_continuous -> A simple continuous state-action MDP for the classical cart-pole system by Rich Sutton, with actions that describe the continuous force applied to the cart.
# RecSim -> A problem of recommendation systems, with consumers and providers.
# MarsRover -> Multi Rover Navigation, where a group of agent needs to harvest mineral.
# Elevators -> The Elevator domain models evening rush hours when people from different floors in a building want to go down to the bottom floor using elevators.
# NewtonZero -> Example with Newton root-finding method.
# NewLanguage -> Example with new language features.
# UAV_discrete -> Discrete action space version of multi-UAV problem where a group of UAVs have to reach goal positions in the 3d Space.
# UAV_mixed -> Mixed action space version of multi-UAV problem where a group of UAVs have to reach goal positions in the 3d Space.
# UAV_continuous -> Continuous action space version of multi-UAV problem where a group of UAVs have to reach goal positions in the 3d Space.
# SupplyChainNet -> A supply chain network with factory and multiple warehouses.
# SupplyChain -> A supply chain with factory and multiple warehouses.
# RaceCar -> A simple continuous MDP for the racecar problem.
# Wildfire -> A boolean version of the wildfire fighting domain.
# PropDBN -> Simple propositional DBN.
# The building has 5 floors and 1 elevators. Each floor has maximum 3 people waiting. Each elevator can carry maximum of 10 people.
# Discrete environment actions:
# {0: ('e0_movcurdir_0',), 1: ('e0_movcurdir_1',), 2: ('e0_close_0',), 3: ('e0_close_1',), 4: ('e0_open_0',), 5: ('e0_open_1',)}
# Continuous environment actions:
# Dict('move-current-dir___e0': Discrete(2), 'open-door___e0': Discrete(2), 'close-door___e0': Discrete(2))
# Observation space size for the discrete Elevator Environment: 225280

# %% [markdown]
# # Hyperparameters

# %%
# Define hyperparameters

## IMPORTANT: <BEGIN> DO NOT CHANGE THIS CODE!
## GENERAL HYPERPARAMS
num_episodes = 3000
## IMPORTANT: <END> DO NOT CHANGE THIS CODE!

learning_rate = 1e-4
batch_size = 64
clip_value = 1.0  # Gradient clipping value
gamma = 0.8
planning_steps = 10
epsilon_decay = 0.998
epsilon = 1.0
epsilon_min = 0.05

## ALGO SPECIFIC HYPERPARAMS
# Update the hyperparams as necessary for your implementation

# %% [markdown]
# # Model Definition
#
# Define your model here. You can rename the class `YourModel` appropriately and use it later in the code.
# Note: In case of actor-critic or other models, all components must subclass `nn.Module`
#
# - Your model should take in 11 inputs, which will be derived from the convert_state_to_list function.
# - Your model should return 6 values corresponding to action logits or probabilities.

# %%
class YourModel(nn.Module):
    def __init__(self):
        super(YourModel, self).__init__()
        # Your model layers and initializations here


    def forward(self, x):
        # x will be a tensor with shape [batch_size, 11]
        # Your forward pass logic here
        # Ensure the output has shape [batch_size, 6]
        return output

# %%
class QNetwork(nn.Module):
    def __init__(self, input_states, output_actions, hidden_size):
        super(QNetwork, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(input_states, hidden_size), nn.ReLU(),
            nn.Linear(hidden_size, hidden_size), nn.ReLU(),
            nn.Linear(hidden_size, output_actions)
        )

    def forward(self, x):
      return self.net(x)

# %%
class ReplayBuffer:
    def __init__(self, capacity):
        self.capacity = capacity
        self.buffer = []
        self.index = 0

    def push(self, state, action, reward, next_state, done):
        if len(self.buffer) < self.capacity:
            self.buffer.append(None)
        self.buffer[self.index] = (state, action, reward, next_state, done)
        self.index = (self.index + 1) % self.capacity

    def sample(self, batch_size):
        return random.sample(self.buffer, batch_size)

    def __len__(self):
        return len(self.buffer)

# %%
class TransitionModel(nn.Module):
    def __init__(self, obs_dim, act_dim):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(obs_dim + act_dim, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, obs_dim + 1)  # next_state + reward
        )

    def forward(self, state, action):
        input = torch.cat([state, action], dim=-1)
        return self.model(input)

# %% [markdown]
# # Feature Extraction

# %%
## IMPORTANT: DO NOT CHANGE THIS CODE!
env_features = list(env.observation_space.keys())

def convert_state_to_list(state, env_features):
    out = []
    for i in env_features:
        out.append(state[i])
    return out

# %% [markdown]
# # Neural Net Initialization

# %%
# Initialize the network and optimizer
input_size = len(env_features)
output_size = 6

# INITIALIZE OTHER NETWORK PARAMS HERE
hidden_size = 128

# INITIALIZE YOUR NETWORK HERE
Qnet = QNetwork(input_size, output_size, hidden_size)
targetNet = QNetwork(input_size, output_size, hidden_size)

# INIT OPTIMIZER - Adam is a good start, but you can try changing this as well
optimizer = optim.Adam(
    Qnet.parameters(), lr=learning_rate
)
replay_buffer = ReplayBuffer(capacity=10000)

# %%
# Convert networks to CUDA if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
Qnet.to(device)
targetNet.to(device)

# Define other constructs (replay buffers, etc) as necessary
# Out:
# QNetwork(
#   (net): Sequential(
#     (0): Linear(in_features=13, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=6, bias=True)
#   )
# )

# %%
targetNet.load_state_dict(Qnet.state_dict())
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Gradient Clipping (Optional, you can use torch's version as well)

# %%
# Define a function for gradient clipping
def clip_grads(model, clip_value):
    for param in model.parameters():
        if param.grad is not None:
            param.grad.data = torch.clamp(param.grad.data, -clip_value, clip_value)

# %%
#Normalize States
def normalize_state(tensor):
    return (tensor - tensor.mean()) / (tensor.std() + 1e-8)

# %%
#Z-score Normalization
class RewardNormalizer:
    def __init__(self):
        self.mean = 0.0
        self.var = 0.0
        self.count = 1e-8

    def normalize(self, reward):
        self.count += 1
        alpha = 1.0 / self.count
        self.mean += alpha * (reward - self.mean)
        self.var += alpha * ((reward - self.mean) ** 2)
        std = np.sqrt(self.var)
        return (reward - self.mean) / (std + 1e-8)

# %% [markdown]
# # Live Plotting Setup

# %%
# Create a figure for plotting
plt.style.use('ggplot')
fig, ax = plt.subplots(figsize=(10, 6))
plt.ion()

# Lists to store rewards and episode numbers
rewards_list = []
episodes = []

def exponential_smoothing(data, alpha=0.1):
    """Compute exponential smoothing."""
    smoothed = [data[0]]  # Initialize with the first data point
    for i in range(1, len(data)):
        st = alpha * data[i] + (1 - alpha) * smoothed[-1]
        smoothed.append(st)
    return smoothed

def live_plot(data_dict, figure, ylabel="Total Rewards"):
    """Plot the live graph."""
    clear_output(wait=True)
    ax.clear()
    for label, data in data_dict.items():
        if label == "Total Reward":
            ax.plot(data, label=label, color="yellow", linestyle='--')

            # Compute and plot moving average for total reward
            ma = exponential_smoothing(data)
            ma_idx_start = len(data) - len(ma)
            ax.plot(range(ma_idx_start, len(data)), ma, label="Smoothed Value", linestyle="-", color="purple", linewidth=2)
        else:
            ax.plot(data, label=label)
    ax.set_ylabel(ylabel)
    ax.legend(loc='upper left')
    display(figure)

# %% [markdown]
# # RL Algorithm

# %%
def choose_action(model, state_tensor, epsilon):
    state_tensor = state_tensor.unsqueeze(0)
    if random.random() < epsilon:
        return random.randint(0, model(state_tensor).shape[1] - 1)
    with torch.no_grad():
        return model(state_tensor).argmax().item()

# %%
# Calculate loss and update Q-network
def calculate_loss(QNet, targetNet, optimizer, state_tensor, action, reward, next_state_tensor, done, gamma):
    state_tensor = state_tensor.unsqueeze(0)
    next_state_tensor = next_state_tensor.unsqueeze(0)

    q_values = QNet(state_tensor)
    with torch.no_grad():
        q_next = targetNet(next_state_tensor)
        target = reward + (0 if done else gamma * q_next.max().item())

    q_target = q_values.clone().detach()
    q_target[0][action] = target

    loss_fn = nn.MSELoss()
    loss = loss_fn(q_values, q_target)

    return loss

# %% [markdown]
# ## Training loop with live plotting
#
# Use the graph generated here in your pdf submission.

# %%
replay_memory = []
fig, ax = plt.subplots(figsize=(10, 6))

plt.style.use('ggplot')
fig, ax = plt.subplots(figsize=(10, 6))
plt.ion()

# Create a tqdm progress bar
progress_bar = tqdm.tqdm(range(num_episodes), postfix={'Total Reward': 0, 'Loss': 0})

gamma = 0.8
learning_rate = 1e-4

planning_steps = 80
epsilon_decay = 0.998
epsilon = 1.0
epsilon_min = 0.05

reward_normalizer = RewardNormalizer()

# RL algorithm training loop
for episode in progress_bar:
    total_reward = 0
    state = env.reset()

    while True:
        # Convert the original state to the suitable format for the network
        state_desc = env.disc2state(state)
        state_list = convert_state_to_list(state_desc, env_features)
        state_tensor = torch.tensor(state_list, dtype=torch.float32, device=device)
        #state_tensor = (state_tensor - state_tensor.mean()) / (state_tensor.std() + 1e-8)
        state_tensor = normalize_state(state_tensor) #Normalize States

        action = choose_action(
            ## TODO: FILL IN PARAMS FOR CALLING choose_action
            Qnet, state_tensor, epsilon
        )

        # Take the chosen action and observe the next state and reward
        next_state, reward, done, _ = env.step((action))
        reward = reward_normalizer.normalize(reward)

        # Convert the next state to the suitable format for the network
        next_state_desc = env.disc2state(next_state)
        next_state_list = convert_state_to_list(next_state_desc, env_features)
        next_state_tensor = torch.tensor(next_state_list, dtype=torch.float32, device=device)
        next_state_tensor = normalize_state(next_state_tensor) #Normalize States


        # Hint: You may want to collect experiences from the environment to update the agent in batches!
        replay_buffer.push(state_tensor, action, reward, next_state_tensor, done)

        # loss = calculate_loss(Qnet, targetNet, optimizer, state_tensor, action, reward, next_state_tensor, done, gamma)

        # optimizer.zero_grad()
        # loss.backward()
        # #Clip Gradient
        # torch.nn.utils.clip_grad_norm_(Qnet.parameters(), max_norm=1.0)
        # optimizer.step()

        #Batch Update
        if len(replay_buffer) >= batch_size:
            batch = replay_buffer.sample(batch_size)
            for s, a, r, ns, d in batch:
                #Normalize Rewards
                r = reward_normalizer.normalize(r)

                #Normalize States
                s = normalize_state(s)
                ns = normalize_state(ns)

                loss = calculate_loss(Qnet, targetNet, optimizer, s, a, r, ns, d, gamma)
                optimizer.zero_grad()
                #Clip Gradient
                torch.nn.utils.clip_grad_norm_(Qnet.parameters(), max_norm=1.0)
                loss.backward()
                optimizer.step()

        if len(replay_buffer) >= batch_size:
            for _ in range(planning_steps):
                s, a, r, ns, d = random.choice(replay_buffer.buffer)

                #Normalize Rewards
                r = reward_normalizer.normalize(r)

                #Normalize States
                s = normalize_state(s)
                ns = normalize_state(ns)

                loss_p = calculate_loss(Qnet, targetNet, optimizer,s, a, r, ns, d, gamma)
                optimizer.zero_grad()
                #Clip Gradient
                torch.nn.utils.clip_grad_norm_(Qnet.parameters(), max_norm=1.0)
                loss_p.backward()
                optimizer.step()

        state = next_state
        total_reward += reward

        if done:
            break

    if episode % 10 == 0:
        targetNet.load_state_dict(Qnet.state_dict())

    rewards_list.append(total_reward)
    episodes.append(episode)

    #epsilon decay
    epsilon = max(epsilon * epsilon_decay, epsilon_min)

    live_plot({'Total Reward': rewards_list}, fig)

    # Saving the model
    if episode%500 == 0:
      torch.save(Qnet, f'model.pt')

    progress_bar.set_postfix({'Total Reward': total_reward, 'Loss': loss.item(), 'Epsilon': epsilon})
# Out:
#  74%|███████▎  | 2210/3000 [10:33:02<3:37:22, 16.51s/it, Total Reward=-57, Loss=0.395, Epsilon=0.05]

# %% [markdown]
# ## Compute the mean rewards
#
# Report the mean rewards obtained in your pdf submission

# %%
mean_rewards = sum(rewards_list) / len(rewards_list)
print(f"\nMean Rewards: {mean_rewards}")

# close the environment
env.close()
# Out:
# Mean Rewards: -164933.4092887557

# %%
torch.save(Qnet, '/content/drive/My Drive/Colab/modelDynaQ.pt')

# %%
final_model = torch.load('/content/drive/My Drive/Colab/modelDynaQ.pt', weights_only=False)
final_model.eval()

trained_network = final_model

# %%
is_render = True
render_path = '/content/drive/MyDrive/Colab/' # path to the folder on your google drive
env = Elevator(is_render=is_render, render_path=render_path, instance = 5)

# reset environment
state = env.reset(seed=40)

total_reward = 0
for t in range(env.horizon):
    state_desc = env.disc2state(state)
    state_list = convert_state_to_list(state_desc, env_features)
    state_tensor = torch.tensor(state_list, dtype=torch.float32, device=device)
    state_tensor = normalize_state(state_tensor) #Normalize States

    # sample random action
    action = choose_action(
            ## TODO: FILL IN PARAMS FOR CALLING choose_action
            Qnet, state_tensor, epsilon
        )

    # take an action
    next_state, reward, terminated, info = env.step(action)  # self.env.step(action)

    if is_render:
        env.render()

    total_reward += reward
    print()
    print(f'state      = {state}')
    print(f'action     = {action}')
    print(f'next state = {next_state}')
    print(f'reward     = {reward}')
    print(f'total_reward     = {total_reward}')
    state = next_state

env.close()
# Out:
# /usr/local/lib/python3.11/dist-packages/pyRDDLGym/Examples /usr/local/lib/python3.11/dist-packages/pyRDDLGym/Examples/manifest.csv
# Available example environment(s):
# MountainCar -> A simple continuous MDP for the classical mountain car control problem.
# HVAC -> Multi-zone and multi-heater HVAC control problem
# PowerGen_discrete -> A simple power generation problem loosely modeled on the problem of unit commitment.
# PowerGen_continuous -> A continuous simple power generation problem loosely modeled on the problem of unit commitment.
# Traffic -> BLX/QTM traffic model.
# Reservoir_discrete -> Discrete version of management of the water level in interconnected reservoirs.
# Reservoir_continuous -> Continuous action version of management of the water level in interconnected reservoirs.
# CartPole_discrete -> A simple continuous state MDP for the classical cart-pole system by Rich Sutton, with discrete actions that apply a constant force on either the left or right side of the cart.
# CartPole_continuous -> A simple continuous state-action MDP for the classical cart-pole system by Rich Sutton, with actions that describe the continuous force applied to the cart.
# RecSim -> A problem of recommendation systems, with consumers and providers.
# MarsRover -> Multi Rover Navigation, where a group of agent needs to harvest mineral.
# Elevators -> The Elevator domain models evening rush hours when people from different floors in a building want to go down to the bottom floor using elevators.
# NewtonZero -> Example with Newton root-finding method.
# NewLanguage -> Example with new language features.
# UAV_discrete -> Discrete action space version of multi-UAV problem where a group of UAVs have to reach goal positions in the 3d Space.
# UAV_mixed -> Mixed action space version of multi-UAV problem where a group of UAVs have to reach goal positions in the 3d Space.
# UAV_continuous -> Continuous action space version of multi-UAV problem where a group of UAVs have to reach goal positions in the 3d Space.
# SupplyChainNet -> A supply chain network with factory and multiple warehouses.
# SupplyChain -> A supply chain with factory and multiple warehouses.
# RaceCar -> A simple continuous MDP for the racecar problem.
# Wildfire -> A boolean version of the wildfire fighting domain.
# PropDBN -> Simple propositional DBN.
# The building has 5 floors and 1 elevators. Each floor has maximum 3 people waiting. Each elevator can carry maximum of 10 people.
# /usr/local/lib/python3.11/dist-packages/pyRDDLGym/Core/Env/RDDLConstraints.py:85: UserWarning: Constraint does not have a structure of <action or state fluent> <op> <rhs>, where:
# <op> is one of {<=, <, >=, >}
# <rhs> is a deterministic function of non-fluents or constants only.
# >> ( sum_{?f: floor} [ elevator-at-floor(?e, ?f) ] ) == 1
#   warnings.warn(
# state      = 2048
# action     = 4
# next state = 2052
# reward     = 0.0
# total_reward     = 0.0
#
# state      = 2052
# action     = 4
# next state = 2116
# reward     = -3.0
# total_reward     = -3.0
#
# state      = 2116
# action     = 4
# next state = 2116
# reward     = -6.0
# total_reward     = -9.0
#
# state      = 2116
# action     = 4
# next state = 2116
# reward     = -6.0
# total_reward     = -15.0
#
# state      = 2116
# action     = 4
# next state = 2116
# reward     = -6.0
# total_reward     = -21.0
#
# state      = 2116
# action     = 4
# next state = 2116
# reward     = -6.0
# total_reward     = -27.0
#
# state      = 2116
# action     = 4
# next state = 2116
# reward     = -6.0
# total_reward     = -33.0
#
# state      = 2116
# action     = 4
# next state = 2116
# reward     = -6.0
# total_reward     = -39.0
#
# state      = 2116
# action     = 4
# next state = 2116
# reward     = -6.0
# total_reward     = -45.0
#
# state      = 2116
# action     = 4
# next state = 2116
# reward     = -6.0
# total_reward     = -51.0
#
# state      = 2116
# action     = 4
# next state = 2116
# reward     = -6.0
# total_reward     = -57.0
#
# state      = 2116
# action     = 4
# next state = 2116
# reward     = -6.0
# total_reward     = -63.0
#
# state      = 2116
# action     = 4
# next state = 2116
# reward     = -6.0
# total_reward     = -69.0
#
# state      = 2116
# action     = 4
# next state = 2132
# reward     = -6.0
# total_reward     = -75.0
#
# state      = 2132
# action     = 4
# next state = 2196
# reward     = -9.0
# total_reward     = -84.0
#
# state      = 2196
# action     = 4
# next state = 2197
# reward     = -12.0
# total_reward     = -96.0
#
# state      = 2197
# action     = 4
# next state = 2261
# reward     = -15.0
# total_reward     = -111.0
#
# state      = 2261
# action     = 4
# next state = 2281
# reward     = -18.0
# total_reward     = -129.0
#
# state      = 2281
# action     = 1
# next state = 6393
# reward     = -24.0
# total_reward     = -153.0
#
# state      = 6393
# action     = 5
# next state = 5370
# reward     = -27.0
# total_reward     = -180.0
#
# state      = 5370
# action     = 1
# next state = 66618
# reward     = -30.0
# total_reward     = -210.0
#
# state      = 66618
# action     = 4
# next state = 66618
# reward     = -21.75
# total_reward     = -231.75
#
# state      = 66618
# action     = 1
# next state = 66618
# reward     = -21.75
# total_reward     = -253.5
#
# state      = 66618
# action     = 1
# next state = 66622
# reward     = -21.75
# total_reward     = -275.25
#
# state      = 66622
# action     = 1
# next state = 66622
# reward     = -24.75
# total_reward     = -300.0
#
# state      = 66622
# action     = 1
# next state = 66622
# reward     = -24.75
# total_reward     = -324.75
#
# state      = 66622
# action     = 1
# next state = 66623
# reward     = -24.75
# total_reward     = -349.5
#
# state      = 66623
# action     = 2
# next state = 66623
# reward     = -27.75
# total_reward     = -377.25
#
# state      = 66623
# action     = 2
# next state = 66623
# reward     = -27.75
# total_reward     = -405.0
#
# state      = 66623
# action     = 2
# next state = 66623
# reward     = -27.75
# total_reward     = -432.75
#
# state      = 66623
# action     = 2
# next state = 66623
# reward     = -27.75
# total_reward     = -460.5
#
# state      = 66623
# action     = 2
# next state = 66623
# reward     = -27.75
# total_reward     = -488.25
#
# state      = 66623
# action     = 1
# next state = 66623
# reward     = -27.75
# total_reward     = -516.0
#
# state      = 66623
# action     = 2
# next state = 66623
# reward     = -27.75
# total_reward     = -543.75
#
# state      = 66623
# action     = 2
# next state = 66623
# reward     = -27.75
# total_reward     = -571.5
#
# state      = 66623
# action     = 2
# next state = 66623
# reward     = -27.75
# total_reward     = -599.25
#
# state      = 66623
# action     = 2
# next state = 66623
# reward     = -27.75
# total_reward     = -627.0
#
# state      = 66623
# action     = 2
# next state = 66623
# reward     = -27.75
# total_reward     = -654.75
#
# state      = 66623
# action     = 2
# next state = 66751
# reward     = -27.75
# total_reward     = -682.5
#
# state      = 66751
# action     = 2
# next state = 107647
# reward     = -33.75
# total_reward     = -716.25
#
# state      = 107647
# action     = 3
# next state = 127039
# reward     = -30.75
# total_reward     = -747.0
#
# state      = 127039
# action     = 1
# next state = 122943
# reward     = -27.75
# total_reward     = -774.75
#
# state      = 122943
# action     = 4
# next state = 2175
# reward     = 152.25
# total_reward     = -622.5
#
# state      = 2175
# action     = 1
# next state = 6335
# reward     = -30.0
# total_reward     = -652.5
#
# state      = 6335
# action     = 1
# next state = 10495
# reward     = -33.0
# total_reward     = -685.5
#
# state      = 10495
# action     = 1
# next state = 14591
# reward     = -36.0
# total_reward     = -721.5
#
# state      = 14591
# action     = 5
# next state = 13567
# reward     = -36.0
# total_reward     = -757.5
#
# state      = 13567
# action     = 1
# next state = 74995
# reward     = -36.0
# total_reward     = -793.5
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -821.25
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -849.0
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -876.75
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -904.5
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -932.25
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -960.0
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -987.75
#
# state      = 74995
# action     = 5
# next state = 74995
# reward     = -27.75
# total_reward     = -1015.5
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -1043.25
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -1071.0
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -1098.75
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -1126.5
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -1154.25
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -1182.0
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -1209.75
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -1237.5
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -1265.25
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -1293.0
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -1320.75
#
# state      = 74995
# action     = 1
# next state = 74999
# reward     = -27.75
# total_reward     = -1348.5
#
# state      = 74999
# action     = 1
# next state = 95475
# reward     = -30.75
# total_reward     = -1379.25
#
# state      = 95475
# action     = 1
# next state = 95479
# reward     = -27.75
# total_reward     = -1407.0
#
# state      = 95479
# action     = 1
# next state = 115955
# reward     = -30.75
# total_reward     = -1437.75
#
# state      = 115955
# action     = 1
# next state = 115955
# reward     = -27.75
# total_reward     = -1465.5
#
# state      = 115955
# action     = 1
# next state = 115955
# reward     = -27.75
# total_reward     = -1493.25
#
# state      = 115955
# action     = 1
# next state = 115955
# reward     = -27.75
# total_reward     = -1521.0
#
# state      = 115955
# action     = 1
# next state = 115955
# reward     = -27.75
# total_reward     = -1548.75
#
# state      = 115955
# action     = 1
# next state = 115955
# reward     = -27.75
# total_reward     = -1576.5
#
# state      = 115955
# action     = 1
# next state = 115955
# reward     = -27.75
# total_reward     = -1604.25
#
# state      = 115955
# action     = 1
# next state = 115955
# reward     = -27.75
# total_reward     = -1632.0
#
# state      = 115955
# action     = 1
# next state = 115959
# reward     = -27.75
# total_reward     = -1659.75
#
# state      = 115959
# action     = 5
# next state = 136439
# reward     = -30.75
# total_reward     = -1690.5
#
# state      = 136439
# action     = 5
# next state = 156919
# reward     = -30.75
# total_reward     = -1721.25
#
# state      = 156919
# action     = 5
# next state = 177395
# reward     = -30.75
# total_reward     = -1752.0
#
# state      = 177395
# action     = 1
# next state = 177395
# reward     = -27.75
# total_reward     = -1779.75
#
# state      = 177395
# action     = 2
# next state = 177395
# reward     = -27.75
# total_reward     = -1807.5
#
# state      = 177395
# action     = 1
# next state = 177395
# reward     = -27.75
# total_reward     = -1835.25
#
# state      = 177395
# action     = 1
# next state = 177395
# reward     = -27.75
# total_reward     = -1863.0
#
# state      = 177395
# action     = 1
# next state = 177399
# reward     = -27.75
# total_reward     = -1890.75
#
# state      = 177399
# action     = 1
# next state = 197875
# reward     = -30.75
# total_reward     = -1921.5
#
# state      = 197875
# action     = 1
# next state = 197875
# reward     = -27.75
# total_reward     = -1949.25
#
# state      = 197875
# action     = 1
# next state = 197875
# reward     = -27.75
# total_reward     = -1977.0
#
# state      = 197875
# action     = 1
# next state = 197875
# reward     = -27.75
# total_reward     = -2004.75
#
# state      = 197875
# action     = 1
# next state = 197875
# reward     = -27.75
# total_reward     = -2032.5
#
# state      = 197875
# action     = 1
# next state = 197875
# reward     = -27.75
# total_reward     = -2060.25
#
# state      = 197875
# action     = 1
# next state = 197875
# reward     = -27.75
# total_reward     = -2088.0
#
# state      = 197875
# action     = 1
# next state = 197875
# reward     = -27.75
# total_reward     = -2115.75
#
# state      = 197875
# action     = 1
# next state = 197879
# reward     = -27.75
# total_reward     = -2143.5
#
# state      = 197879
# action     = 1
# next state = 218355
# reward     = -30.75
# total_reward     = -2174.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2202.0
#
# state      = 218355
# action     = 5
# next state = 218363
# reward     = -27.75
# total_reward     = -2229.75
#
# state      = 218363
# action     = 0
# next state = 218359
# reward     = -33.75
# total_reward     = -2263.5
#
# state      = 218359
# action     = 5
# next state = 218355
# reward     = -30.75
# total_reward     = -2294.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2322.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2349.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2377.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2405.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2433.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2460.75
#
# state      = 218355
# action     = 1
# next state = 218359
# reward     = -27.75
# total_reward     = -2488.5
#
# state      = 218359
# action     = 5
# next state = 218355
# reward     = -30.75
# total_reward     = -2519.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2547.0
#
# state      = 218355
# action     = 4
# next state = 218355
# reward     = -27.75
# total_reward     = -2574.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2602.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2630.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2658.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2685.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2713.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2741.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2769.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2796.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2824.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2852.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2880.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2907.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2935.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2963.25
#
# state      = 218355
# action     = 5
# next state = 218359
# reward     = -27.75
# total_reward     = -2991.0
#
# state      = 218359
# action     = 5
# next state = 218355
# reward     = -30.75
# total_reward     = -3021.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3049.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3077.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3105.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3132.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3160.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3188.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3216.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3243.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3271.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3299.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3327.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3354.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3382.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3410.25
#
# state      = 218355
# action     = 1
# next state = 218359
# reward     = -27.75
# total_reward     = -3438.0
#
# state      = 218359
# action     = 5
# next state = 218355
# reward     = -30.75
# total_reward     = -3468.75
#
# state      = 218355
# action     = 4
# next state = 218355
# reward     = -27.75
# total_reward     = -3496.5
#
# state      = 218355
# action     = 5
# next state = 218363
# reward     = -27.75
# total_reward     = -3524.25
#
# state      = 218363
# action     = 1
# next state = 218359
# reward     = -33.75
# total_reward     = -3558.0
#
# state      = 218359
# action     = 5
# next state = 218355
# reward     = -30.75
# total_reward     = -3588.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3616.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3644.25
#
# state      = 218355
# action     = 5
# next state = 218359
# reward     = -27.75
# total_reward     = -3672.0
#
# state      = 218359
# action     = 5
# next state = 218355
# reward     = -30.75
# total_reward     = -3702.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3730.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3758.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3786.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3813.75
#
# state      = 218355
# action     = 5
# next state = 218359
# reward     = -27.75
# total_reward     = -3841.5
#
# state      = 218359
# action     = 5
# next state = 218355
# reward     = -30.75
# total_reward     = -3872.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3900.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3927.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3955.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3983.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4011.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4038.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4066.5
#
# state      = 218355
# action     = 5
# next state = 218359
# reward     = -27.75
# total_reward     = -4094.25
#
# state      = 218359
# action     = 5
# next state = 218355
# reward     = -30.75
# total_reward     = -4125.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4152.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4180.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4208.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4236.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4263.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4291.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4319.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4347.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4374.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4402.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4430.25
#
# state      = 218355
# action     = 5
# next state = 218359
# reward     = -27.75
# total_reward     = -4458.0
#
# state      = 218359
# action     = 5
# next state = 218355
# reward     = -30.75
# total_reward     = -4488.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4516.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4544.25
#
# state      = 218355
# action     = 5
# next state = 218359
# reward     = -27.75
# total_reward     = -4572.0
#
# state      = 218359
# action     = 5
# next state = 218355
# reward     = -30.75
# total_reward     = -4602.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4630.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4658.25
#
# state      = 218355
# action     = 2
# next state = 218355
# reward     = -27.75
# total_reward     = -4686.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4713.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4741.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4769.25
#
# state      = 218355
# action     = 5
# next state = 218359
# reward     = -27.75
# total_reward     = -4797.0
#
# state      = 218359
# action     = 5
# next state = 218363
# reward     = -30.75
# total_reward     = -4827.75
#
# state      = 218363
# action     = 1
# next state = 218355
# reward     = -33.75
# total_reward     = -4861.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4889.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4917.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4944.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4972.5
#
# state      = 218355
# action     = 5
# next state = 218359
# reward     = -27.75
# total_reward     = -5000.25
#
# state      = 218359
# action     = 5
# next state = 218355
# reward     = -30.75
# total_reward     = -5031.0
#
# state      = 218355
# action     = 2
# next state = 218355
# reward     = -27.75
# total_reward     = -5058.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -5086.5

# %%
if is_render:
    env.save_render()

from IPython.display import Image

display(Image(filename=f'{render_path}/elevator.gif'))

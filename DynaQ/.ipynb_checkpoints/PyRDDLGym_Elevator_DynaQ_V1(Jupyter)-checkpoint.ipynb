# %% [markdown]
# # Installation and setup
#
# The gym environment requires an older version numpy (and corresponding packages). <br>
# The following cell contains the `requirements.txt` to setup the python environment used in the rest of this notebook.

# %%
# %%writefile requirements.txt
#
# cloudpickle==3.1.1
# contourpy==1.3.0
# cycler==0.12.1
# filelock==3.18.0
# fonttools==4.56.0
# fsspec==2025.3.0
# gym==0.26.2
# gym-notices==0.0.8
# importlib_metadata==8.6.1
# importlib_resources==6.5.2
# Jinja2==3.1.6
# kiwisolver==1.4.7
# MarkupSafe==3.0.2
# matplotlib==3.9.4
# #outdated visualizer in github for textViz.py in Visualizer
# #matplotlib==3.3.4 #3.5.0 is minimum for pyrddl 1.0 (the lowest versions)
# mpmath==1.3.0
# networkx==3.2.1
# numpy==1.26.4
# nvidia-cublas-cu12==12.4.5.8
# nvidia-cuda-cupti-cu12==12.4.127
# nvidia-cuda-nvrtc-cu12==12.4.127
# nvidia-cuda-runtime-cu12==12.4.127
# nvidia-cudnn-cu12==9.1.0.70
# nvidia-cufft-cu12==11.2.1.3
# nvidia-curand-cu12==10.3.5.147
# nvidia-cusolver-cu12==11.6.1.9
# nvidia-cusparse-cu12==12.3.1.170
# nvidia-cusparselt-cu12==0.6.2
# #nvidia-nccl-cu12==2.21.5 #Linux specific, install directly from pytorch index link and don't install this manually.
# nvidia-nvjitlink-cu12==12.4.127
# nvidia-nvtx-cu12==12.4.127
# packaging==24.2
# pillow==11.1.0
# ply==3.11
# pygame==2.6.1
# pyparsing==3.2.1
# python-dateutil==2.9.0.post0
# six==1.17.0
# sympy==1.13.1
# torch==2.6.0
# tqdm==4.67.1
# #triton==3.2.0 ##Linux specific, install directly from pytorch index link and don't install this manually.
# zipp==3.21.0
# pyRDDLGym
# Out:
# Overwriting requirements.txt

# %% [markdown]
# Now install the requirements.
#
# You may be asked to restart the session to load the installed versions of the packages. If so, restart the session and continue using the notebook

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: cloudpickle==3.1.1 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 2)) (3.1.1)
# Collecting contourpy==1.3.0 (from -r requirements.txt (line 3))
#   Downloading contourpy-1.3.0-cp310-cp310-win_amd64.whl.metadata (5.4 kB)
# Requirement already satisfied: cycler==0.12.1 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: filelock==3.18.0 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 5)) (3.18.0)
# Collecting fonttools==4.56.0 (from -r requirements.txt (line 6))
#   Downloading fonttools-4.56.0-cp310-cp310-win_amd64.whl.metadata (103 kB)
# Requirement already satisfied: fsspec==2025.3.0 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 7)) (2025.3.0)
# Requirement already satisfied: gym==0.26.2 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 8)) (0.26.2)
# Requirement already satisfied: gym-notices==0.0.8 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 9)) (0.0.8)
# Requirement already satisfied: importlib_metadata==8.6.1 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 10)) (8.6.1)
# Requirement already satisfied: importlib_resources==6.5.2 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 11)) (6.5.2)
# Requirement already satisfied: Jinja2==3.1.6 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 12)) (3.1.6)
# Collecting kiwisolver==1.4.7 (from -r requirements.txt (line 13))
#   Downloading kiwisolver-1.4.7-cp310-cp310-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: MarkupSafe==3.0.2 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 14)) (3.0.2)
# Collecting matplotlib==3.9.4 (from -r requirements.txt (line 15))
#   Downloading matplotlib-3.9.4-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: mpmath==1.3.0 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 18)) (1.3.0)
# Requirement already satisfied: networkx==3.2.1 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 19)) (3.2.1)
# Collecting numpy==1.26.4 (from -r requirements.txt (line 20))
#   Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 21)) (12.4.5.8)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 22)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 23)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 24)) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 25)) (9.1.0.70)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 26)) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 27)) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 28)) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 29)) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 30)) (0.6.2)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 32)) (12.4.127)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 33)) (12.4.127)
# Collecting packaging==24.2 (from -r requirements.txt (line 34))
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pillow==11.1.0 (from -r requirements.txt (line 35))
#   Downloading pillow-11.1.0-cp310-cp310-win_amd64.whl.metadata (9.3 kB)
# Requirement already satisfied: ply==3.11 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 36)) (3.11)
# Requirement already satisfied: pygame==2.6.1 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 37)) (2.6.1)
# Collecting pyparsing==3.2.1 (from -r requirements.txt (line 38))
#   Downloading pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 39)) (2.9.0.post0)
# Requirement already satisfied: six==1.17.0 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 40)) (1.17.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 41)) (1.13.1)
# Requirement already satisfied: torch==2.6.0 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 42)) (2.6.0+cu124)
# Requirement already satisfied: tqdm==4.67.1 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 43)) (4.67.1)
# Requirement already satisfied: zipp==3.21.0 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 45)) (3.21.0)
# Requirement already satisfied: pyRDDLGym in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from -r requirements.txt (line 46)) (1.1.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from torch==2.6.0->-r requirements.txt (line 42)) (4.13.2)
# Requirement already satisfied: colorama in c:\users\julia\documents\github\discreterlalgo\rlvenv\lib\site-packages (from tqdm==4.67.1->-r requirements.txt (line 43)) (0.4.6)
# Downloading contourpy-1.3.0-cp310-cp310-win_amd64.whl (216 kB)
# Downloading fonttools-4.56.0-cp310-cp310-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 41.2 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.7-cp310-cp310-win_amd64.whl (55 kB)
# Downloading matplotlib-3.9.4-cp310-cp310-win_amd64.whl (7.8 MB)
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---------------------------------------- 7.8/7.8 MB 48.5 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    ----------------------------------- ---- 13.9/15.8 MB 67.2 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 66.4 MB/s eta 0:00:00
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
# Downloading pillow-11.1.0-cp310-cp310-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 2.6/2.6 MB 50.3 MB/s eta 0:00:00
# Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
# Installing collected packages: pyparsing, pillow, packaging, numpy, kiwisolver, fonttools, contourpy, matplotlib
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.2.3
#     Uninstalling pyparsing-3.2.3:
#       Successfully uninstalled pyparsing-3.2.3
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.2.1
#     Uninstalling pillow-11.2.1:
#       Successfully uninstalled pillow-11.2.1
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.4
#     Uninstalling numpy-2.2.4:
#       Successfully uninstalled numpy-2.2.4
#   Attempting uninstall: kiwisolver
#     Found existing installation: kiwisolver 1.4.8
#     Uninstalling kiwisolver-1.4.8:
#       Successfully uninstalled kiwisolver-1.4.8
#   Attempting uninstall: fonttools
#     Found existing installation: fonttools 4.57.0
#     Uninstalling fonttools-4.57.0:
#       Successfully uninstalled fonttools-4.57.0
#   Attempting uninstall: contourpy
#     Found existing installation: contourpy 1.3.2
#     Uninstalling contourpy-1.3.2:
#       Successfully uninstalled contourpy-1.3.2
# Successfully installed contourpy-1.3.0 fonttools-4.56.0 kiwisolver-1.4.7 matplotlib-3.9.4 numpy-1.26.4 packaging-24.2 pillow-11.1.0 pyparsing-3.2.1

# %% [markdown]
# We will use a discretized version of
# the [elevator domain](https://ataitler.github.io/IPPC2023/elevator.html) from the International Planning Competition, 2023.
#
# Install the pyRDDL gym environment using the given repository.

# %%
# !pip install -q git+https://github.com/June-Han/pyRDDLGym_NUS.git --force-reinstall

## Install other packages if needed

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import copy
import itertools
import numpy as np
import random
import tqdm
import IPython
from IPython.display import display, clear_output
import matplotlib.pyplot as plt
from collections import deque

from pyRDDLGym.Visualizer.MovieGenerator import MovieGenerator # loads visualizer utilites
from IPython.display import Image, display, clear_output # for displaying gifs in colab
from pyRDDLGym.Elevator import Elevator # imports Discrete Elevator

## Add more imports here as required

# %% [markdown]
# # Environment Initialization

# %%
## IMPORTANT: Do not change the instance of the environment.
env = Elevator(instance = 5)

print('Discrete environment actions:')
print(env.disc_actions)
print('Continuous environment actions:')
print(env.base_env.action_space)
print(f"Observation space size for the discrete Elevator Environment: {len(env.disc_states)}")
# Out:
# C:\Users\julia\Documents\GitHub\DiscreteRLAlgo\RLvenv\lib\site-packages\pyRDDLGym\Examples C:\Users\julia\Documents\GitHub\DiscreteRLAlgo\RLvenv\lib\site-packages\pyRDDLGym\Examples\manifest.csv
# Available example environment(s):
# CartPole_continuous -> A simple continuous state-action MDP for the classical cart-pole system by Rich Sutton, with actions that describe the continuous force applied to the cart.
# CartPole_discrete -> A simple continuous state MDP for the classical cart-pole system by Rich Sutton, with discrete actions that apply a constant force on either the left or right side of the cart.
# Elevators -> The Elevator domain models evening rush hours when people from different floors in a building want to go down to the bottom floor using elevators.
# HVAC -> Multi-zone and multi-heater HVAC control problem
# MarsRover -> Multi Rover Navigation, where a group of agent needs to harvest mineral.
# MountainCar -> A simple continuous MDP for the classical mountain car control problem.
# NewLanguage -> Example with new language features.
# NewtonZero -> Example with Newton root-finding method.
# PowerGen_continuous -> A continuous simple power generation problem loosely modeled on the problem of unit commitment.
# PowerGen_discrete -> A simple power generation problem loosely modeled on the problem of unit commitment.
# PropDBN -> Simple propositional DBN.
# RaceCar -> A simple continuous MDP for the racecar problem.
# RecSim -> A problem of recommendation systems, with consumers and providers.
# Reservoir_continuous -> Continuous action version of management of the water level in interconnected reservoirs.
# Reservoir_discrete -> Discrete version of management of the water level in interconnected reservoirs.
# SupplyChain -> A supply chain with factory and multiple warehouses.
# SupplyChainNet -> A supply chain network with factory and multiple warehouses.
# Traffic -> BLX/QTM traffic model.
# UAV_continuous -> Continuous action space version of multi-UAV problem where a group of UAVs have to reach goal positions in the 3d Space.
# UAV_discrete -> Discrete action space version of multi-UAV problem where a group of UAVs have to reach goal positions in the 3d Space.
# UAV_mixed -> Mixed action space version of multi-UAV problem where a group of UAVs have to reach goal positions in the 3d Space.
# Wildfire -> A boolean version of the wildfire fighting domain.
# The building has 5 floors and 1 elevators. Each floor has maximum 3 people waiting. Each elevator can carry maximum of 10 people.
# Discrete environment actions:
# {0: ('e0_movcurdir_0',), 1: ('e0_movcurdir_1',), 2: ('e0_close_0',), 3: ('e0_close_1',), 4: ('e0_open_0',), 5: ('e0_open_1',)}
# Continuous environment actions:
# Dict('move-current-dir___e0': Discrete(2), 'open-door___e0': Discrete(2), 'close-door___e0': Discrete(2))
# Observation space size for the discrete Elevator Environment: 225280

# %% [markdown]
# # Hyperparameters

# %%
# Define hyperparameters

## IMPORTANT: <BEGIN> DO NOT CHANGE THIS CODE!
## GENERAL HYPERPARAMS
num_episodes = 3000
## IMPORTANT: <END> DO NOT CHANGE THIS CODE!

learning_rate = 1e-4
batch_size = 64
clip_value = 1.0  # Gradient clipping value
gamma = 0.8
planning_steps = 10
epsilon_decay = 0.998
epsilon = 1.0
epsilon_min = 0.05

## ALGO SPECIFIC HYPERPARAMS
# Update the hyperparams as necessary for your implementation

# %% [markdown]
# # Model Definition
#
# Define your model here. You can rename the class `YourModel` appropriately and use it later in the code.
# Note: In case of actor-critic or other models, all components must subclass `nn.Module`
#
# - Your model should take in 11 inputs, which will be derived from the convert_state_to_list function.
# - Your model should return 6 values corresponding to action logits or probabilities.

# %%
class YourModel(nn.Module):
    def __init__(self):
        super(YourModel, self).__init__()
        # Your model layers and initializations here


    def forward(self, x):
        # x will be a tensor with shape [batch_size, 11]
        # Your forward pass logic here
        # Ensure the output has shape [batch_size, 6]
        return output

# %%
class QNetwork(nn.Module):
    def __init__(self, input_states, output_actions, hidden_size):
        super(QNetwork, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(input_states, hidden_size), nn.ReLU(),
            nn.Linear(hidden_size, hidden_size), nn.ReLU(),
            nn.Linear(hidden_size, output_actions)
        )

    def forward(self, x):
      return self.net(x)

# %%
class ReplayBuffer:
    def __init__(self, capacity):
        self.capacity = capacity
        self.buffer = []
        self.index = 0

    def push(self, state, action, reward, next_state, done):
        if len(self.buffer) < self.capacity:
            self.buffer.append(None)
        self.buffer[self.index] = (state, action, reward, next_state, done)
        self.index = (self.index + 1) % self.capacity

    def sample(self, batch_size):
        return random.sample(self.buffer, batch_size)

    def __len__(self):
        return len(self.buffer)

# %%
#Unused
class TransitionModel(nn.Module):
    def __init__(self, obs_dim, act_dim):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(obs_dim + act_dim, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, obs_dim + 1)  # next_state + reward
        )

    def forward(self, state, action):
        input = torch.cat([state, action], dim=-1)
        return self.model(input)

# %% [markdown]
# # Feature Extraction

# %%
## IMPORTANT: DO NOT CHANGE THIS CODE!
env_features = list(env.observation_space.keys())

def convert_state_to_list(state, env_features):
    out = []
    for i in env_features:
        out.append(state[i])
    return out

# %% [markdown]
# # Neural Net Initialization

# %%
# Initialize the network and optimizer
input_size = len(env_features)
output_size = 6

# INITIALIZE OTHER NETWORK PARAMS HERE
hidden_size = 128

# INITIALIZE YOUR NETWORK HERE
Qnet = QNetwork(input_size, output_size, hidden_size)
targetNet = QNetwork(input_size, output_size, hidden_size)

# INIT OPTIMIZER - Adam is a good start, but you can try changing this as well
optimizer = optim.Adam(
    Qnet.parameters(), lr=learning_rate
)
replay_buffer = ReplayBuffer(capacity=10000)

# %%
# Convert networks to CUDA if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
Qnet.to(device)
targetNet.to(device)

# Define other constructs (replay buffers, etc) as necessary
# Out:
# QNetwork(
#   (net): Sequential(
#     (0): Linear(in_features=13, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=6, bias=True)
#   )
# )

# %%
targetNet.load_state_dict(Qnet.state_dict())
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Gradient Clipping (Optional, you can use torch's version as well)

# %%
# Define a function for gradient clipping
def clip_grads(model, clip_value):
    for param in model.parameters():
        if param.grad is not None:
            param.grad.data = torch.clamp(param.grad.data, -clip_value, clip_value)

# %%
#Normalize States
def normalize_state(tensor):
    return (tensor - tensor.mean()) / (tensor.std() + 1e-8)

# %%
#Z-score Normalization
class RewardNormalizer:
    def __init__(self):
        self.mean = 0.0
        self.var = 0.0
        self.count = 1e-8

    def normalize(self, reward):
        self.count += 1
        alpha = 1.0 / self.count
        self.mean += alpha * (reward - self.mean)
        self.var += alpha * ((reward - self.mean) ** 2)
        std = np.sqrt(self.var)
        return (reward - self.mean) / (std + 1e-8)

# %% [markdown]
# # Live Plotting Setup

# %%
# %matplotlib inline
# from IPython.display import display, clear_output
# Create a figure for plotting
plt.style.use('ggplot')
fig, ax = plt.subplots(figsize=(10, 6))
plt.ion()

# Lists to store rewards and episode numbers
rewards_list = []
episodes = []

def exponential_smoothing(data, alpha=0.1):
    """Compute exponential smoothing."""
    smoothed = [data[0]]  # Initialize with the first data point
    for i in range(1, len(data)):
        st = alpha * data[i] + (1 - alpha) * smoothed[-1]
        smoothed.append(st)
    return smoothed

def live_plot(data_dict, figure, ylabel="Total Rewards"):
    """Plot the live graph."""
    clear_output(wait=True)
    ax.clear()
    for label, data in data_dict.items():
        if label == "Total Reward":
            ax.plot(data, label=label, color="yellow", linestyle='--')

            # Compute and plot moving average for total reward
            ma = exponential_smoothing(data)
            ma_idx_start = len(data) - len(ma)
            ax.plot(range(ma_idx_start, len(data)), ma, label="Smoothed Value", linestyle="-", color="purple", linewidth=2)
        else:
            ax.plot(data, label=label)
    ax.set_ylabel(ylabel)
    ax.set_xlabel("Episode")
    ax.set_title("Live Training Plot")
    ax.legend(loc='upper left')
    display(figure)

# %% [markdown]
# # RL Algorithm

# %%
def choose_action(model, state_tensor, epsilon):
    state_tensor = state_tensor.unsqueeze(0)
    if random.random() < epsilon:
        return random.randint(0, model(state_tensor).shape[1] - 1)
    with torch.no_grad():
        return model(state_tensor).argmax().item()

# %%
# Calculate loss and update Q-network
def calculate_loss(QNet, targetNet, optimizer, state_tensor, action, reward, next_state_tensor, done, gamma):
    state_tensor = state_tensor.unsqueeze(0)
    next_state_tensor = next_state_tensor.unsqueeze(0)

    q_values = QNet(state_tensor)
    with torch.no_grad():
        q_next = targetNet(next_state_tensor)
        target = reward + (0 if done else gamma * q_next.max().item())

    q_target = q_values.clone().detach()
    q_target[0][action] = target

    loss_fn = nn.MSELoss()
    loss = loss_fn(q_values, q_target)

    return loss

# %% [markdown]
# ## Training loop with live plotting
#
# Use the graph generated here in your pdf submission.

# %%
# %matplotlib inline
replay_memory = []
fig, ax = plt.subplots(figsize=(10, 6))

plt.style.use('ggplot')
fig, ax = plt.subplots(figsize=(10, 6))
plt.ion()

# Create a tqdm progress bar
progress_bar = tqdm.tqdm(range(num_episodes), postfix={'Total Reward': 0, 'Loss': 0})

gamma = 0.8
learning_rate = 1e-4

planning_steps = 80
epsilon_decay = 0.998
epsilon = 1.0
epsilon_min = 0.05

reward_normalizer = RewardNormalizer()

# RL algorithm training loop
for episode in progress_bar:
    total_reward = 0
    state = env.reset()

    while True:
        # Convert the original state to the suitable format for the network
        state_desc = env.disc2state(state)
        state_list = convert_state_to_list(state_desc, env_features)
        state_tensor = torch.tensor(state_list, dtype=torch.float32, device=device)
        #state_tensor = (state_tensor - state_tensor.mean()) / (state_tensor.std() + 1e-8)
        state_tensor = normalize_state(state_tensor) #Normalize States

        action = choose_action(
            ## TODO: FILL IN PARAMS FOR CALLING choose_action
            Qnet, state_tensor, epsilon
        )

        # Take the chosen action and observe the next state and reward
        next_state, reward, done, _ = env.step((action))
        reward = reward_normalizer.normalize(reward)

        # Convert the next state to the suitable format for the network
        next_state_desc = env.disc2state(next_state)
        next_state_list = convert_state_to_list(next_state_desc, env_features)
        next_state_tensor = torch.tensor(next_state_list, dtype=torch.float32, device=device)
        next_state_tensor = normalize_state(next_state_tensor) #Normalize States


        # Hint: You may want to collect experiences from the environment to update the agent in batches!
        replay_buffer.push(state_tensor, action, reward, next_state_tensor, done)

        # loss = calculate_loss(Qnet, targetNet, optimizer, state_tensor, action, reward, next_state_tensor, done, gamma)

        # optimizer.zero_grad()
        # loss.backward()
        # #Clip Gradient
        # torch.nn.utils.clip_grad_norm_(Qnet.parameters(), max_norm=1.0)
        # optimizer.step()

        #Batch Update
        if len(replay_buffer) >= batch_size:
            batch = replay_buffer.sample(batch_size)
            for s, a, r, ns, d in batch:
                #Normalize Rewards
                r = reward_normalizer.normalize(r)

                #Normalize States
                s = normalize_state(s)
                ns = normalize_state(ns)

                loss = calculate_loss(Qnet, targetNet, optimizer, s, a, r, ns, d, gamma)
                optimizer.zero_grad()
                #Clip Gradient
                torch.nn.utils.clip_grad_norm_(Qnet.parameters(), max_norm=1.0)
                loss.backward()
                optimizer.step()

        if len(replay_buffer) >= batch_size:
            for _ in range(planning_steps):
                s, a, r, ns, d = random.choice(replay_buffer.buffer)

                #Normalize Rewards
                r = reward_normalizer.normalize(r)

                #Normalize States
                s = normalize_state(s)
                ns = normalize_state(ns)

                loss_p = calculate_loss(Qnet, targetNet, optimizer,s, a, r, ns, d, gamma)
                optimizer.zero_grad()
                #Clip Gradient
                torch.nn.utils.clip_grad_norm_(Qnet.parameters(), max_norm=1.0)
                loss_p.backward()
                optimizer.step()

        state = next_state
        total_reward += reward

        if done:
            break

    if episode % 10 == 0:
        targetNet.load_state_dict(Qnet.state_dict())

    rewards_list.append(total_reward)
    episodes.append(episode)

    #epsilon decay
    epsilon = max(epsilon * epsilon_decay, epsilon_min)

    live_plot({'Total Reward': rewards_list}, fig)

    # Saving the model
    if episode%500 == 0:
      torch.save(Qnet, f'model.pt')

    progress_bar.set_postfix({'Total Reward': total_reward, 'Loss': loss.item(), 'Epsilon': epsilon})
# Out:
#  10%|██▌                       | 295/3000 [5:22:14<55:09:49, 73.42s/it, Total Reward=-272, Loss=4.52e-5, Epsilon=0.554]

# %% [markdown]
# ## Compute the mean rewards
#
# Report the mean rewards obtained in your pdf submission

# %%
mean_rewards = sum(rewards_list) / len(rewards_list)
print(f"\nMean Rewards: {mean_rewards}")

# close the environment
env.close()
# Out:
# Mean Rewards: -164933.4092887557

# %%
torch.save(Qnet, './modelDynaQ.pt')

# %%
final_model = torch.load('./modelDynaQ.pt', weights_only=False)
final_model.eval()

trained_network = final_model

# %%
is_render = True
render_path = './' # path to the folder on your google drive
env = Elevator(is_render=is_render, render_path=render_path, instance = 5)

# reset environment
state = env.reset(seed=40)

total_reward = 0
for t in range(env.horizon):
    state_desc = env.disc2state(state)
    state_list = convert_state_to_list(state_desc, env_features)
    state_tensor = torch.tensor(state_list, dtype=torch.float32, device=device)
    state_tensor = normalize_state(state_tensor) #Normalize States

    # sample random action
    action = choose_action(
            ## TODO: FILL IN PARAMS FOR CALLING choose_action
            Qnet, state_tensor, epsilon
        )

    # take an action
    next_state, reward, terminated, info = env.step(action)  # self.env.step(action)

    if is_render:
        env.render()

    total_reward += reward
    print()
    print(f'state      = {state}')
    print(f'action     = {action}')
    print(f'next state = {next_state}')
    print(f'reward     = {reward}')
    print(f'total_reward     = {total_reward}')
    state = next_state

env.close()
# Out:
# /usr/local/lib/python3.11/dist-packages/pyRDDLGym/Examples /usr/local/lib/python3.11/dist-packages/pyRDDLGym/Examples/manifest.csv
# Available example environment(s):
# MountainCar -> A simple continuous MDP for the classical mountain car control problem.
# HVAC -> Multi-zone and multi-heater HVAC control problem
# PowerGen_discrete -> A simple power generation problem loosely modeled on the problem of unit commitment.
# PowerGen_continuous -> A continuous simple power generation problem loosely modeled on the problem of unit commitment.
# Traffic -> BLX/QTM traffic model.
# Reservoir_discrete -> Discrete version of management of the water level in interconnected reservoirs.
# Reservoir_continuous -> Continuous action version of management of the water level in interconnected reservoirs.
# CartPole_discrete -> A simple continuous state MDP for the classical cart-pole system by Rich Sutton, with discrete actions that apply a constant force on either the left or right side of the cart.
# CartPole_continuous -> A simple continuous state-action MDP for the classical cart-pole system by Rich Sutton, with actions that describe the continuous force applied to the cart.
# RecSim -> A problem of recommendation systems, with consumers and providers.
# MarsRover -> Multi Rover Navigation, where a group of agent needs to harvest mineral.
# Elevators -> The Elevator domain models evening rush hours when people from different floors in a building want to go down to the bottom floor using elevators.
# NewtonZero -> Example with Newton root-finding method.
# NewLanguage -> Example with new language features.
# UAV_discrete -> Discrete action space version of multi-UAV problem where a group of UAVs have to reach goal positions in the 3d Space.
# UAV_mixed -> Mixed action space version of multi-UAV problem where a group of UAVs have to reach goal positions in the 3d Space.
# UAV_continuous -> Continuous action space version of multi-UAV problem where a group of UAVs have to reach goal positions in the 3d Space.
# SupplyChainNet -> A supply chain network with factory and multiple warehouses.
# SupplyChain -> A supply chain with factory and multiple warehouses.
# RaceCar -> A simple continuous MDP for the racecar problem.
# Wildfire -> A boolean version of the wildfire fighting domain.
# PropDBN -> Simple propositional DBN.
# The building has 5 floors and 1 elevators. Each floor has maximum 3 people waiting. Each elevator can carry maximum of 10 people.
# /usr/local/lib/python3.11/dist-packages/pyRDDLGym/Core/Env/RDDLConstraints.py:85: UserWarning: Constraint does not have a structure of <action or state fluent> <op> <rhs>, where:
# <op> is one of {<=, <, >=, >}
# <rhs> is a deterministic function of non-fluents or constants only.
# >> ( sum_{?f: floor} [ elevator-at-floor(?e, ?f) ] ) == 1
#   warnings.warn(
# state      = 2048
# action     = 4
# next state = 2052
# reward     = 0.0
# total_reward     = 0.0
#
# state      = 2052
# action     = 4
# next state = 2116
# reward     = -3.0
# total_reward     = -3.0
#
# state      = 2116
# action     = 4
# next state = 2116
# reward     = -6.0
# total_reward     = -9.0
#
# state      = 2116
# action     = 4
# next state = 2116
# reward     = -6.0
# total_reward     = -15.0
#
# state      = 2116
# action     = 4
# next state = 2116
# reward     = -6.0
# total_reward     = -21.0
#
# state      = 2116
# action     = 4
# next state = 2116
# reward     = -6.0
# total_reward     = -27.0
#
# state      = 2116
# action     = 4
# next state = 2116
# reward     = -6.0
# total_reward     = -33.0
#
# state      = 2116
# action     = 4
# next state = 2116
# reward     = -6.0
# total_reward     = -39.0
#
# state      = 2116
# action     = 4
# next state = 2116
# reward     = -6.0
# total_reward     = -45.0
#
# state      = 2116
# action     = 4
# next state = 2116
# reward     = -6.0
# total_reward     = -51.0
#
# state      = 2116
# action     = 4
# next state = 2116
# reward     = -6.0
# total_reward     = -57.0
#
# state      = 2116
# action     = 4
# next state = 2116
# reward     = -6.0
# total_reward     = -63.0
#
# state      = 2116
# action     = 4
# next state = 2116
# reward     = -6.0
# total_reward     = -69.0
#
# state      = 2116
# action     = 4
# next state = 2132
# reward     = -6.0
# total_reward     = -75.0
#
# state      = 2132
# action     = 4
# next state = 2196
# reward     = -9.0
# total_reward     = -84.0
#
# state      = 2196
# action     = 4
# next state = 2197
# reward     = -12.0
# total_reward     = -96.0
#
# state      = 2197
# action     = 4
# next state = 2261
# reward     = -15.0
# total_reward     = -111.0
#
# state      = 2261
# action     = 4
# next state = 2281
# reward     = -18.0
# total_reward     = -129.0
#
# state      = 2281
# action     = 1
# next state = 6393
# reward     = -24.0
# total_reward     = -153.0
#
# state      = 6393
# action     = 5
# next state = 5370
# reward     = -27.0
# total_reward     = -180.0
#
# state      = 5370
# action     = 1
# next state = 66618
# reward     = -30.0
# total_reward     = -210.0
#
# state      = 66618
# action     = 4
# next state = 66618
# reward     = -21.75
# total_reward     = -231.75
#
# state      = 66618
# action     = 1
# next state = 66618
# reward     = -21.75
# total_reward     = -253.5
#
# state      = 66618
# action     = 1
# next state = 66622
# reward     = -21.75
# total_reward     = -275.25
#
# state      = 66622
# action     = 1
# next state = 66622
# reward     = -24.75
# total_reward     = -300.0
#
# state      = 66622
# action     = 1
# next state = 66622
# reward     = -24.75
# total_reward     = -324.75
#
# state      = 66622
# action     = 1
# next state = 66623
# reward     = -24.75
# total_reward     = -349.5
#
# state      = 66623
# action     = 2
# next state = 66623
# reward     = -27.75
# total_reward     = -377.25
#
# state      = 66623
# action     = 2
# next state = 66623
# reward     = -27.75
# total_reward     = -405.0
#
# state      = 66623
# action     = 2
# next state = 66623
# reward     = -27.75
# total_reward     = -432.75
#
# state      = 66623
# action     = 2
# next state = 66623
# reward     = -27.75
# total_reward     = -460.5
#
# state      = 66623
# action     = 2
# next state = 66623
# reward     = -27.75
# total_reward     = -488.25
#
# state      = 66623
# action     = 1
# next state = 66623
# reward     = -27.75
# total_reward     = -516.0
#
# state      = 66623
# action     = 2
# next state = 66623
# reward     = -27.75
# total_reward     = -543.75
#
# state      = 66623
# action     = 2
# next state = 66623
# reward     = -27.75
# total_reward     = -571.5
#
# state      = 66623
# action     = 2
# next state = 66623
# reward     = -27.75
# total_reward     = -599.25
#
# state      = 66623
# action     = 2
# next state = 66623
# reward     = -27.75
# total_reward     = -627.0
#
# state      = 66623
# action     = 2
# next state = 66623
# reward     = -27.75
# total_reward     = -654.75
#
# state      = 66623
# action     = 2
# next state = 66751
# reward     = -27.75
# total_reward     = -682.5
#
# state      = 66751
# action     = 2
# next state = 107647
# reward     = -33.75
# total_reward     = -716.25
#
# state      = 107647
# action     = 3
# next state = 127039
# reward     = -30.75
# total_reward     = -747.0
#
# state      = 127039
# action     = 1
# next state = 122943
# reward     = -27.75
# total_reward     = -774.75
#
# state      = 122943
# action     = 4
# next state = 2175
# reward     = 152.25
# total_reward     = -622.5
#
# state      = 2175
# action     = 1
# next state = 6335
# reward     = -30.0
# total_reward     = -652.5
#
# state      = 6335
# action     = 1
# next state = 10495
# reward     = -33.0
# total_reward     = -685.5
#
# state      = 10495
# action     = 1
# next state = 14591
# reward     = -36.0
# total_reward     = -721.5
#
# state      = 14591
# action     = 5
# next state = 13567
# reward     = -36.0
# total_reward     = -757.5
#
# state      = 13567
# action     = 1
# next state = 74995
# reward     = -36.0
# total_reward     = -793.5
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -821.25
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -849.0
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -876.75
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -904.5
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -932.25
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -960.0
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -987.75
#
# state      = 74995
# action     = 5
# next state = 74995
# reward     = -27.75
# total_reward     = -1015.5
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -1043.25
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -1071.0
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -1098.75
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -1126.5
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -1154.25
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -1182.0
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -1209.75
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -1237.5
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -1265.25
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -1293.0
#
# state      = 74995
# action     = 1
# next state = 74995
# reward     = -27.75
# total_reward     = -1320.75
#
# state      = 74995
# action     = 1
# next state = 74999
# reward     = -27.75
# total_reward     = -1348.5
#
# state      = 74999
# action     = 1
# next state = 95475
# reward     = -30.75
# total_reward     = -1379.25
#
# state      = 95475
# action     = 1
# next state = 95479
# reward     = -27.75
# total_reward     = -1407.0
#
# state      = 95479
# action     = 1
# next state = 115955
# reward     = -30.75
# total_reward     = -1437.75
#
# state      = 115955
# action     = 1
# next state = 115955
# reward     = -27.75
# total_reward     = -1465.5
#
# state      = 115955
# action     = 1
# next state = 115955
# reward     = -27.75
# total_reward     = -1493.25
#
# state      = 115955
# action     = 1
# next state = 115955
# reward     = -27.75
# total_reward     = -1521.0
#
# state      = 115955
# action     = 1
# next state = 115955
# reward     = -27.75
# total_reward     = -1548.75
#
# state      = 115955
# action     = 1
# next state = 115955
# reward     = -27.75
# total_reward     = -1576.5
#
# state      = 115955
# action     = 1
# next state = 115955
# reward     = -27.75
# total_reward     = -1604.25
#
# state      = 115955
# action     = 1
# next state = 115955
# reward     = -27.75
# total_reward     = -1632.0
#
# state      = 115955
# action     = 1
# next state = 115959
# reward     = -27.75
# total_reward     = -1659.75
#
# state      = 115959
# action     = 5
# next state = 136439
# reward     = -30.75
# total_reward     = -1690.5
#
# state      = 136439
# action     = 5
# next state = 156919
# reward     = -30.75
# total_reward     = -1721.25
#
# state      = 156919
# action     = 5
# next state = 177395
# reward     = -30.75
# total_reward     = -1752.0
#
# state      = 177395
# action     = 1
# next state = 177395
# reward     = -27.75
# total_reward     = -1779.75
#
# state      = 177395
# action     = 2
# next state = 177395
# reward     = -27.75
# total_reward     = -1807.5
#
# state      = 177395
# action     = 1
# next state = 177395
# reward     = -27.75
# total_reward     = -1835.25
#
# state      = 177395
# action     = 1
# next state = 177395
# reward     = -27.75
# total_reward     = -1863.0
#
# state      = 177395
# action     = 1
# next state = 177399
# reward     = -27.75
# total_reward     = -1890.75
#
# state      = 177399
# action     = 1
# next state = 197875
# reward     = -30.75
# total_reward     = -1921.5
#
# state      = 197875
# action     = 1
# next state = 197875
# reward     = -27.75
# total_reward     = -1949.25
#
# state      = 197875
# action     = 1
# next state = 197875
# reward     = -27.75
# total_reward     = -1977.0
#
# state      = 197875
# action     = 1
# next state = 197875
# reward     = -27.75
# total_reward     = -2004.75
#
# state      = 197875
# action     = 1
# next state = 197875
# reward     = -27.75
# total_reward     = -2032.5
#
# state      = 197875
# action     = 1
# next state = 197875
# reward     = -27.75
# total_reward     = -2060.25
#
# state      = 197875
# action     = 1
# next state = 197875
# reward     = -27.75
# total_reward     = -2088.0
#
# state      = 197875
# action     = 1
# next state = 197875
# reward     = -27.75
# total_reward     = -2115.75
#
# state      = 197875
# action     = 1
# next state = 197879
# reward     = -27.75
# total_reward     = -2143.5
#
# state      = 197879
# action     = 1
# next state = 218355
# reward     = -30.75
# total_reward     = -2174.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2202.0
#
# state      = 218355
# action     = 5
# next state = 218363
# reward     = -27.75
# total_reward     = -2229.75
#
# state      = 218363
# action     = 0
# next state = 218359
# reward     = -33.75
# total_reward     = -2263.5
#
# state      = 218359
# action     = 5
# next state = 218355
# reward     = -30.75
# total_reward     = -2294.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2322.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2349.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2377.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2405.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2433.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2460.75
#
# state      = 218355
# action     = 1
# next state = 218359
# reward     = -27.75
# total_reward     = -2488.5
#
# state      = 218359
# action     = 5
# next state = 218355
# reward     = -30.75
# total_reward     = -2519.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2547.0
#
# state      = 218355
# action     = 4
# next state = 218355
# reward     = -27.75
# total_reward     = -2574.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2602.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2630.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2658.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2685.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2713.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2741.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2769.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2796.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2824.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2852.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2880.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2907.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2935.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -2963.25
#
# state      = 218355
# action     = 5
# next state = 218359
# reward     = -27.75
# total_reward     = -2991.0
#
# state      = 218359
# action     = 5
# next state = 218355
# reward     = -30.75
# total_reward     = -3021.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3049.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3077.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3105.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3132.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3160.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3188.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3216.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3243.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3271.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3299.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3327.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3354.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3382.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3410.25
#
# state      = 218355
# action     = 1
# next state = 218359
# reward     = -27.75
# total_reward     = -3438.0
#
# state      = 218359
# action     = 5
# next state = 218355
# reward     = -30.75
# total_reward     = -3468.75
#
# state      = 218355
# action     = 4
# next state = 218355
# reward     = -27.75
# total_reward     = -3496.5
#
# state      = 218355
# action     = 5
# next state = 218363
# reward     = -27.75
# total_reward     = -3524.25
#
# state      = 218363
# action     = 1
# next state = 218359
# reward     = -33.75
# total_reward     = -3558.0
#
# state      = 218359
# action     = 5
# next state = 218355
# reward     = -30.75
# total_reward     = -3588.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3616.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3644.25
#
# state      = 218355
# action     = 5
# next state = 218359
# reward     = -27.75
# total_reward     = -3672.0
#
# state      = 218359
# action     = 5
# next state = 218355
# reward     = -30.75
# total_reward     = -3702.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3730.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3758.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3786.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3813.75
#
# state      = 218355
# action     = 5
# next state = 218359
# reward     = -27.75
# total_reward     = -3841.5
#
# state      = 218359
# action     = 5
# next state = 218355
# reward     = -30.75
# total_reward     = -3872.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3900.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3927.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3955.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -3983.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4011.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4038.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4066.5
#
# state      = 218355
# action     = 5
# next state = 218359
# reward     = -27.75
# total_reward     = -4094.25
#
# state      = 218359
# action     = 5
# next state = 218355
# reward     = -30.75
# total_reward     = -4125.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4152.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4180.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4208.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4236.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4263.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4291.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4319.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4347.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4374.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4402.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4430.25
#
# state      = 218355
# action     = 5
# next state = 218359
# reward     = -27.75
# total_reward     = -4458.0
#
# state      = 218359
# action     = 5
# next state = 218355
# reward     = -30.75
# total_reward     = -4488.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4516.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4544.25
#
# state      = 218355
# action     = 5
# next state = 218359
# reward     = -27.75
# total_reward     = -4572.0
#
# state      = 218359
# action     = 5
# next state = 218355
# reward     = -30.75
# total_reward     = -4602.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4630.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4658.25
#
# state      = 218355
# action     = 2
# next state = 218355
# reward     = -27.75
# total_reward     = -4686.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4713.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4741.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4769.25
#
# state      = 218355
# action     = 5
# next state = 218359
# reward     = -27.75
# total_reward     = -4797.0
#
# state      = 218359
# action     = 5
# next state = 218363
# reward     = -30.75
# total_reward     = -4827.75
#
# state      = 218363
# action     = 1
# next state = 218355
# reward     = -33.75
# total_reward     = -4861.5
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4889.25
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4917.0
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4944.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -4972.5
#
# state      = 218355
# action     = 5
# next state = 218359
# reward     = -27.75
# total_reward     = -5000.25
#
# state      = 218359
# action     = 5
# next state = 218355
# reward     = -30.75
# total_reward     = -5031.0
#
# state      = 218355
# action     = 2
# next state = 218355
# reward     = -27.75
# total_reward     = -5058.75
#
# state      = 218355
# action     = 5
# next state = 218355
# reward     = -27.75
# total_reward     = -5086.5

# %%
if is_render:
    env.save_render()

from IPython.display import Image

display(Image(filename=f'{render_path}/elevator.gif'))
